# %%
import pandas as pd

# %%
# Create the kaggle directory
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# Read the uploaded kaggle.json file
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat '/content/drive/MyDrive/kaggle.json': No such file or directory

# %%
# Download dataset
# !kaggle datasets download joebeachcapital/airbnb
# Out:
# Dataset URL: https://www.kaggle.com/datasets/joebeachcapital/airbnb
# License(s): CC0-1.0
# ...
#  99% 1.00G/1.01G [00:09<00:00, 131MB/s]
# 100% 1.01G/1.01G [00:09<00:00, 110MB/s]

# %%
# Unzip folder in Colab content folder
# !unzip /content/airbnb.zip
# Out:
# Archive:  /content/airbnb.zip
#   inflating: airbnb-listings.csv
#   inflating: airbnb-listings.geojson

# %%
# Read the csv files into pandas df
airbnb = pd.read_csv('airbnb-listings.csv', delimiter=';', quotechar='"')
# Out:
# <ipython-input-11-8026b52ac2b9>:2: DtypeWarning: Columns (0,2,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   airbnb = pd.read_csv('airbnb-listings.csv', delimiter=';', quotechar='"')

# %%
airbnb = airbnb[['ID', 'Neighbourhood', 'City', 'State', 'Country', 'Latitude', 'Longitude', 'Property Type', 'Accommodates', 'Bathrooms',
                 'Bedrooms', 'Beds', 'Price', 'Guests Included', 'Extra People', 'Minimum Nights', 'Maximum Nights', 'Number of Reviews',
                 'Review Scores Rating']]

# %%
airbnb = airbnb.dropna()

# %%
airbnb
# Out:
#               ID      Neighbourhood            City          State  \
# 0        4008728           Oud-West       Amsterdam  North Holland
# 1        7778612           Oud-West       Amsterdam  Noord-Holland
# 2        8264596           Oud-West       Amsterdam  Noord-Holland
# 3        2180729           Oud-West       Amsterdam  Noord-Holland
# 4       14463171                NaN       Amsterdam  Noord-Holland
# ...          ...                ...             ...            ...
# 494949  12856943          Footscray       Footscray            VIC
# 494950   4567157  Yarraville/Seddon      Yarraville            VIC
# 494951  16681466                NaN  West Footscray            VIC
# 494952  17179364                NaN       Footscray            VIC
# 494953  10735664  Yarraville/Seddon      Kingsville            VIC
#
#             Country   Latitude   Longitude Property Type  Accommodates  \
# 0       Netherlands  52.365237    4.878250     Apartment           6.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
airbnb.to_csv('/content/drive/MyDrive/airbnb_cleaned.csv')
